# %% [markdown]
# # Masked Language Modelling
#
# **Module 14** — BERT & Bidirectional Pre-Training
#
# > From the [Zylo Learning Platform](https://socrapy-local.vercel.app) Sequence Models course.

# %% [markdown]
# ## Context
#
# Take a sentence. Randomly mask 15% of the tokens. Ask the model to predict the masked tokens from the surrounding context. That's it.

# %% [markdown]
# ## Code

# %%
# Input:  "The cat [MASK] on the [MASK]"
# Target: "The cat sat   on the mat"
# The model must predict 'sat' and 'mat' from context

# %% [markdown]
# ## Key Takeaway
#
# This is a fill-in-the-blank task. To predict the masked word, the model must understand the full context — both the words to the left AND the words to the right. This is the critical difference from GPT, which only sees left context.
#
# ---
#
# *Generated from the [Zylo Sequence Models Course](https://socrapy-local.vercel.app). Continue learning at the platform for interactive exercises, quizzes, and AI tutoring.*
