# %% [markdown]
# # The Transformer Block: Attention + FFN + Residuals
#
# **Module 13** — Self-Attention & the Transformer
#
# > From the [Zylo Learning Platform](https://socrapy-local.vercel.app) Sequence Models course.

# %% [markdown]
# ## Context
#
# A single **Transformer block** has this structure:

# %% [markdown]
# ## Code

# %%
# Transformer Block (pseudocode)
# Input: X of shape (T, d_model)

# Sub-layer 1: Multi-Head Self-Attention + Residual + LayerNorm
attn_out = MultiHeadAttention(X, X, X)   # self-attention
X = LayerNorm(X + attn_out)              # residual connection + normalize

# Sub-layer 2: Feed-Forward Network + Residual + LayerNorm
ffn_out = FFN(X)                         # position-wise FFN
X = LayerNorm(X + ffn_out)               # residual connection + normalize

# Output: X of shape (T, d_model) — same shape as input!

# %% [markdown]
# ## Key Takeaway
#
# Let's break down each component:
#
# ---
#
# *Generated from the [Zylo Sequence Models Course](https://socrapy-local.vercel.app). Continue learning at the platform for interactive exercises, quizzes, and AI tutoring.*
