# %% [markdown]
# # Queries, Keys, Values, and Scaled Dot-Product
#
# **Module 13** — Self-Attention & the Transformer
#
# > From the [Zylo Learning Platform](https://socrapy-local.vercel.app) Sequence Models course.

# %% [markdown]
# ## Context
#
# Given an input matrix **X** of shape `(T, d_model)` where T is the sequence length and d_model is the embedding dimension, we compute:
#
# > **Note:** Think of it like a library search. Your **query** is what you're looking for. Each book has a **key** (its title/description). You compare your query against all keys to find the best match. Then you retrieve the **value** (the book's actual content). Self-attention is exactly this — but every word

# %% [markdown]
# ## Code

# %%
# Q, K, V are all linear projections of the same input X
Q = X @ W_Q  # (T, d_k) — what am I looking for?
K = X @ W_K  # (T, d_k) — what do I contain?
V = X @ W_V  # (T, d_v) — what information do I carry?

# %% [markdown]
# ## Key Takeaway
#
# The attention computation is then:
#
# ---
#
# *Generated from the [Zylo Sequence Models Course](https://socrapy-local.vercel.app). Continue learning at the platform for interactive exercises, quizzes, and AI tutoring.*
